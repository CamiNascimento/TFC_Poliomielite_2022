# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn

# %%
dfIR = pd.read_csv("DadosCompletos.csv", index_col=3)
#print(dfIR)

# %%
dfDados = pd.read_csv("DadosCompletos.csv", index_col=0)

# %% [markdown]
# # Mapas por estados e regiões da cobetura vacinal VS as outras variáveis

# %% [markdown]
# ### Sudeste

# %%
MG=dfIR.loc["Minas Gerais"]
plt.scatter(MG['Média Var At Pr'], MG['Média Var CobVac'], c="blue")
plt.title("Minas Gerais - Var CobVac VS Var At Pr")
plt.xlabel("Cobertura Atenção Primária")
plt.ylabel("Cobertura Vacinal")
plt.savefig('Minas Gerais - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(MG['Média Var Plano'], MG['Média Var CobVac'], c="blue")
plt.title("Minas Gerais - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Minas Gerais - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(MG['Média At Pr'], MG['Média Cob Vac'], c="blue")
plt.title("Minas Gerais - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Minas Gerais - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(MG['Média Plano'], MG['Média Cob Vac'], c="blue")
plt.title("Minas Gerais - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Minas Gerais - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(MG['IDHm'], MG['Média Cob Vac'], c="blue")
plt.title("Minas Gerais - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Minas Gerais - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

# %%
ES=dfIR.loc["Espírito Santo"]
plt.scatter(ES['Média Var At Pr'],ES['Média Var CobVac'], c="green")
plt.title("Espírito Santo - Var CobVac VS Var At Pr")
plt.xlabel("Cobertura Atenção Primária")
plt.ylabel("Cobertura Vacinal")
plt.savefig('Espírito Santo - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(ES['Média Var Plano'], ES['Média Var CobVac'], c="green")
plt.title("Espírito Santo - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Espírito Santo - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(ES['Média At Pr'], ES['Média Cob Vac'], c="green")
plt.title("Espírito Santo - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Espírito Santo - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(ES['Média Plano'], ES['Média Cob Vac'], c="green")
plt.title("Espírito Santo - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Espírito Santo - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(ES['IDHm'], ES['Média Cob Vac'], c="green")
plt.title("Espírito Santo - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Espírito Santo - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

SU1=plt.scatter(ES['Média Var At Pr'],ES['Média Var CobVac'], c="green")

# %%
RJ=dfIR.loc["Rio de Janeiro"]
plt.scatter(RJ['Média Var At Pr'],RJ['Média Var CobVac'], c="red")
plt.title("Rio de Janeiro - Var CobVac VS Var At Pr")
plt.xlabel("Cobertura Atenção Primária")
plt.ylabel("Cobertura Vacinal")
plt.savefig('Rio de Janeiro - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(RJ['Média Var Plano'], RJ['Média Var CobVac'], c="red")
plt.title("Rio de Janeiro - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Rio de Janeiro - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(RJ['Média At Pr'], RJ['Média Cob Vac'], c="red")
plt.title("Rio de Janeiro - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Rio de Janeiro - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(RJ['Média Plano'], RJ['Média Cob Vac'], c="red")
plt.title("Rio de Janeiro - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Rio de Janeiro - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(RJ['IDHm'], RJ['Média Cob Vac'], c="red")
plt.title("Rio de Janeiro - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Rio de Janeiro - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

# %%
SP=dfIR.loc["São Paulo"]
plt.scatter(SP['Média Var At Pr'],SP['Média Var CobVac'], c="purple")
plt.title("São Paulo - Var CobVac VS Var At Pr")
plt.xlabel("Cobertura Atenção Primária")
plt.ylabel("Cobertura Vacinal")
plt.savefig('São Paulo - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(SP['Média Var Plano'], SP['Média Var CobVac'], c="purple")
plt.title("São Paulo - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('São Paulo - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(SP['Média At Pr'], SP['Média Cob Vac'], c="purple")
plt.title("São Paulo - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('São Paulo - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(SP['Média Plano'], SP['Média Cob Vac'], c="purple")
plt.title("São Paulo- Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('São Paulo- Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(SP['IDHm'], SP['Média Cob Vac'], c="purple")
plt.title("São Paulo - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('São Paulo - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

# %%
#Gráficos REgião Sudeste

SU1=plt.scatter(SP['Média Var At Pr'],SP['Média Var CobVac'], c="purple")
SU1=plt.scatter(MG['Média Var At Pr'], MG['Média Var CobVac'], c="blue")
SU1=plt.scatter(ES['Média Var At Pr'],ES['Média Var CobVac'], c="green")
SU1=plt.scatter(RJ['Média Var At Pr'],RJ['Média Var CobVac'], c="red")
#plt.xlim([-0.2, 0.4])
#plt.ylim([-0.2, 1])
plt.title("Região Sudeste - Var CobVac VS Var At Pr")
plt.xlabel("Cobertura Atenção Primária")
plt.ylabel("Cobertura Vacinal")
plt.savefig('Sudeste - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

SU2=plt.scatter(MG['Média Var Plano'], MG['Média Var CobVac'], c="blue")
SU2=plt.scatter(SP['Média Var Plano'], SP['Média Var CobVac'], c="purple")
SU2=plt.scatter(RJ['Média Var Plano'], RJ['Média Var CobVac'], c="red")
SU2=plt.scatter(ES['Média Var Plano'], ES['Média Var CobVac'], c="green")
plt.xlim([-0.2, 0.4])
plt.ylim([-0.2, 1])
plt.title("Região Sudeste - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Sudeste2 - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

SU3=plt.scatter(MG['Média At Pr'], MG['Média Cob Vac'], c="blue")
SU3=plt.scatter(SP['Média At Pr'], SP['Média Cob Vac'], c="purple")
SU3=plt.scatter(ES['Média At Pr'], ES['Média Cob Vac'], c="green")
SU3=plt.scatter(RJ['Média At Pr'], RJ['Média Cob Vac'], c="red")
#plt.xlim([-0.2, 0.4])
#plt.ylim([-0.2, 1])
plt.title("Região Sudeste - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Sudeste - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

SU4=plt.scatter(MG['Média Plano'], MG['Média Cob Vac'], c="blue")
SU4=plt.scatter(SP['Média Plano'], SP['Média Cob Vac'], c="purple")
SU4=plt.scatter(ES['Média Plano'], ES['Média Cob Vac'], c="green")
SU4=plt.scatter(RJ['Média Plano'], RJ['Média Cob Vac'], c="red")
plt.title("Região Sudeste- Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Sudeste- Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

SU5=plt.scatter(MG['IDHm'], MG['Média Cob Vac'], c="blue")
SU5=plt.scatter(SP['IDHm'], SP['Média Cob Vac'], c="purple")
SU5=plt.scatter(ES['IDHm'], ES['Média Cob Vac'], c="green")
SU5=plt.scatter(RJ['IDHm'], RJ['Média Cob Vac'], c="red")
plt.title("Região Sudeste - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Sudeste - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

SU6=plt.scatter(MG['gini'], MG['Média Cob Vac'], c="blue")
SU6=plt.scatter(SP['gini'], SP['Média Cob Vac'], c="purple")
SU6=plt.scatter(ES['gini'], ES['Média Cob Vac'], c="green")
SU6=plt.scatter(RJ['gini'], RJ['Média Cob Vac'], c="red")
plt.title("Região Sudeste - Média CobVac VS Gini")
plt.xlabel("Gini")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Sudeste - Média CobVac VS Gini.jpg', format='jpg')
plt.show()
plt.clf()

SU7=plt.scatter(MG['Média_pct_pop0a4'], MG['Média Cob Vac'], c="blue")
SU7=plt.scatter(SP['Média_pct_pop0a4'], SP['Média Cob Vac'], c="purple")
SU7=plt.scatter(ES['Média_pct_pop0a4'], ES['Média Cob Vac'], c="green")
SU7=plt.scatter(RJ['Média_pct_pop0a4'], RJ['Média Cob Vac'], c="red")
plt.title("Região Sudeste - Média CobVac VS População de 0 a 4 anos")
plt.xlabel("População de 0 a 4 anos")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Sudeste - Média CobVac VS População de 0 a 4 anos.jpg', format='jpg')
plt.show()
plt.clf()

SU8=plt.scatter(MG['pct_san_adeq'], MG['Média Cob Vac'], c="blue")
SU8=plt.scatter(SP['pct_san_adeq'], SP['Média Cob Vac'], c="purple")
SU8=plt.scatter(ES['pct_san_adeq'], ES['Média Cob Vac'], c="green")
SU8=plt.scatter(RJ['pct_san_adeq'], RJ['Média Cob Vac'], c="red")
plt.title("Região Sudeste - Média CobVac VS Saneamento Básico Adequado")
plt.xlabel("Saneamento Básico Adequado")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Sudeste - Média CobVac VS Saneamento Básico.jpg', format='jpg')
plt.show()
plt.clf()

SU9=plt.scatter(MG['média_pct_ben_bf'], MG['Média Cob Vac'], c="blue")
SU9=plt.scatter(SP['média_pct_ben_bf'], SP['Média Cob Vac'], c="purple")
SU9=plt.scatter(ES['média_pct_ben_bf'], ES['Média Cob Vac'], c="green")
SU9=plt.scatter(RJ['média_pct_ben_bf'], RJ['Média Cob Vac'], c="red")
plt.title("Região Sudeste - Média CobVac VS Beneficiários Bolsa Família")
plt.xlabel("Beneficiários Bolsa Família")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Sudeste - Média CobVac VS Bolsa Família.jpg', format='jpg')
plt.show()
plt.clf()

# %% [markdown]
# ### Centro Oeste

# %%
DF=dfIR.loc["Distrito Federal"]
plt.scatter(DF['Média Var At Pr'], DF['Média Var CobVac'], c="purple")
plt.title("Distrito Federal - Var CobVac VS Var At Pr")
plt.xlabel("Cobertura Atenção Primária")
plt.ylabel("Cobertura Vacinal")
plt.savefig('Distrito Federal - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()


plt.scatter(DF['Média Var Plano'], DF['Média Var CobVac'], c="purple")
plt.title("Distrito Federal - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Distrito Federal - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(DF['Média At Pr'], DF['Média Cob Vac'], c="purple")
plt.title("Distrito Federal - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Distrito Federal - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(DF['Média Plano'], DF['Média Cob Vac'], c="purple")
plt.title("Distrito Federal - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Distrito Federal - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(DF['IDHm'], DF['Média Cob Vac'], c="purple")
plt.title("Distrito Federal - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Distrito Federal - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

# %%
GO=dfIR.loc["Goiás"]
plt.scatter(GO['Média Var At Pr'], GO['Média Var CobVac'], c="blue")
plt.title("Goiás - Var CobVac VS Var At Pr")
plt.xlabel("Cobertura Atenção Primária")
plt.ylabel("Cobertura Vacinal")
plt.savefig('Goiás - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(GO['Média Var Plano'], GO['Média Var CobVac'], c="blue")
plt.title("Goiás - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Goiás - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(GO['Média At Pr'], GO['Média Cob Vac'], c="blue")
plt.title("Goiás - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Goiás - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(GO['Média Plano'], GO['Média Cob Vac'], c="blue")
plt.title("Goiás - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Goiás - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(GO['IDHm'], GO['Média Cob Vac'], c="blue")
plt.title("Goiás - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Goiás - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

# %%
MT=dfIR.loc["Mato Grosso"]
plt.scatter(MT['Média Var At Pr'], MT['Média Var CobVac'], c="green")
plt.title("Mato Grosso - Var CobVac VS At Pr")
plt.xlabel("Cobertura Atenção Primária")
plt.ylabel("Cobertura Vacinal")
plt.savefig('Mato Grosso - Var CobVac VS At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(MT['Média Var Plano'], MT['Média Var CobVac'], c="green")
plt.title("Mato Grosso - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Mato Grosso - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(MT['Média At Pr'], MT['Média Cob Vac'], c="green")
plt.title("Mato Grosso - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Mato Grosso - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(MT['Média Plano'], MT['Média Cob Vac'], c="green")
plt.title("Mato Grosso - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Mato Grosso - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(MT['IDHm'], MT['Média Cob Vac'], c="green")
plt.title("Mato Grosso - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Mato Grosso - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

# %%
MS=dfIR.loc["Mato Grosso do Sul"]
plt.scatter(MS['Média Var At Pr'], MS['Média Var CobVac'], c="red")
plt.title("Mato Grosso do Sul - Var CobVac VS At Pr")
plt.xlabel("Cobertura Atenção Primária")
plt.ylabel("Cobertura Vacinal")
plt.savefig('Mato Grosso do Sul - Var CobVac VS At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(MS['Média Var Plano'], MS['Média Var CobVac'], c="red")
plt.title("Mato Grosso do Sul - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Mato Grosso do Sul - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(MS['Média At Pr'], MS['Média Cob Vac'], c="red")
plt.title("Mato Grosso do Sul - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Mato Grosso do Sul - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(MS['Média Plano'], MS['Média Cob Vac'], c="red")
plt.title("Mato Grosso do Sul - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Mato Grosso do Sul - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(MS['IDHm'], MS['Média Cob Vac'], c="red")
plt.title("Mato Grosso do Sul - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Mato Grosso do Sul - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

# %%
#Gráficos região Centro Oeste

CO1=plt.scatter(GO['Média Var At Pr'], GO['Média Var CobVac'], c="blue")
CO1=plt.scatter(MT['Média Var At Pr'], MT['Média Var CobVac'], c="green")
CO1=plt.scatter(MS['Média Var At Pr'], MS['Média Var CobVac'], c="red")
CO1=plt.scatter(DF['Média Var At Pr'], DF['Média Var CobVac'], c="purple")
plt.xlim([-0.1, 0.2])
plt.ylim([-0.2, 0.5])
plt.title("Região Centro Oeste - Var CobVac VS At Pr")
plt.xlabel("Cobertura Atenção Primária")
plt.ylabel("Cobertura Vacinal")
plt.savefig('Centro Oeste2 - Var CobVac VS At Pr.jpg', format='jpg')
plt.show()
plt.clf()


CO2=plt.scatter(GO['Média Var Plano'], GO['Média Var CobVac'], c="blue")
CO2=plt.scatter(MT['Média Var Plano'], MT['Média Var CobVac'], c="green")
CO2=plt.scatter(MS['Média Var Plano'], MS['Média Var CobVac'], c="red")
CO2=plt.scatter(DF['Média Var Plano'], DF['Média Var CobVac'], c="purple")
plt.xlim([-0.2, 0.4])
plt.ylim([-0.1, 0.2])
plt.title("Região Centro Oeste - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Centro Oeste2 - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

CO3=plt.scatter(GO['Média At Pr'], GO['Média Cob Vac'], c="blue")
CO3=plt.scatter(MS['Média At Pr'], MS['Média Cob Vac'], c="red")
CO3=plt.scatter(MT['Média At Pr'], MT['Média Cob Vac'], c="green")
CO3=plt.scatter(DF['Média At Pr'], DF['Média Cob Vac'], c="purple")
plt.title("Região Centro Oeste - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Centro Oeste - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()


CO4=plt.scatter(MS['Média Plano'], MS['Média Cob Vac'], c="red")
CO4=plt.scatter(MT['Média Plano'], MT['Média Cob Vac'], c="green")
CO4=plt.scatter(GO['Média Plano'], GO['Média Cob Vac'], c="blue")
CO4=plt.scatter(DF['Média Plano'], DF['Média Cob Vac'], c="purple")
plt.title("Região Centro Oeste - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Centro Oeste - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()


CO5=plt.scatter(MS['IDHm'], MS['Média Cob Vac'], c="red")
CO5=plt.scatter(MT['IDHm'], MT['Média Cob Vac'], c="green")
CO5=plt.scatter(GO['IDHm'], GO['Média Cob Vac'], c="blue")
CO5=plt.scatter(DF['IDHm'], DF['Média Cob Vac'], c="purple")
plt.title("Região Centro Oeste - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Centro Oeste - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

CO6=plt.scatter(MS['gini'], MS['Média Cob Vac'], c="red")
CO6=plt.scatter(MT['gini'], MT['Média Cob Vac'], c="green")
CO6=plt.scatter(GO['gini'], GO['Média Cob Vac'], c="blue")
CO6=plt.scatter(DF['gini'], DF['Média Cob Vac'], c="purple")
plt.title("Região Centro Oeste - Média CobVac VS Gini")
plt.xlabel("Gini")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Centro Oeste - Média CobVac VS Gini.jpg', format='jpg')
plt.show()
plt.clf()

CO7=plt.scatter(MS['Média_pct_pop0a4'], MS['Média Cob Vac'], c="red")
CO7=plt.scatter(MT['Média_pct_pop0a4'], MT['Média Cob Vac'], c="green")
CO7=plt.scatter(GO['Média_pct_pop0a4'], GO['Média Cob Vac'], c="blue")
CO7=plt.scatter(DF['Média_pct_pop0a4'], DF['Média Cob Vac'], c="purple")
plt.title("Região Centro Oeste - Média CobVac VS População de 0 a 4 anos")
plt.xlabel("População de 0 a 4 anos")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Centro Oeste - Média CobVac VS População de 0 a 4 anos.jpg', format='jpg')
plt.show()
plt.clf()

CO8=plt.scatter(MS['pct_san_adeq'], MS['Média Cob Vac'], c="red")
CO8=plt.scatter(MT['pct_san_adeq'], MT['Média Cob Vac'], c="green")
CO8=plt.scatter(GO['pct_san_adeq'], GO['Média Cob Vac'], c="blue")
CO8=plt.scatter(DF['pct_san_adeq'], DF['Média Cob Vac'], c="purple")
plt.title("Região Centro Oeste - Média CobVac VS Saneamento Básico Adequado")
plt.xlabel("Saneamento Básico Adequado")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Centro Oeste - Média CobVac VS Saneamento Básico Adequado.jpg', format='jpg')
plt.show()
plt.clf()

CO9=plt.scatter(MS['média_pct_ben_bf'], MS['Média Cob Vac'], c="red")
CO9=plt.scatter(MT['média_pct_ben_bf'], MT['Média Cob Vac'], c="green")
CO9=plt.scatter(GO['média_pct_ben_bf'], GO['Média Cob Vac'], c="blue")
CO9=plt.scatter(DF['média_pct_ben_bf'], DF['Média Cob Vac'], c="purple")
plt.title("Região Centro Oeste - Média CobVac VS Beneficiários Bolsa Família")
plt.xlabel("Beneficiários Bolsa Família")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Centro Oeste - Média CobVac VS Beneficiários Bolsa Família.jpg', format='jpg')
plt.show()
plt.clf()

# %% [markdown]
# ### Nordeste

# %%
AL=dfIR.loc["Alagoas"]
plt.scatter(AL['Média Var At Pr'], AL['Média Var CobVac'], c="blue")
plt.title("Alagoas - Var CobVac VS Var At Pr")
plt.xlabel("Cobertura Atenção Primária")
plt.ylabel("Cobertura Vacinal")
plt.savefig('Alagoas - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(AL['Média Var Plano'], AL['Média Var CobVac'], c="blue")
plt.title("Alagoas - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Alagoas - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(AL['Média At Pr'], AL['Média Cob Vac'], c="blue")
plt.title("Alagoas - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Alagoas - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(AL['Média Plano'], AL['Média Cob Vac'], c="blue")
plt.title("Alagoas - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Alagoas - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(AL['IDHm'], AL['Média Cob Vac'], c="blue")
plt.title("Alagoas - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Alagoas - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

# %%
BA=dfIR.loc["Bahia"]
plt.scatter(BA['Média Var At Pr'], BA['Média Var CobVac'], c="red")
plt.title("Bahia - Var CobVac VS Var At Pr")
plt.xlabel("Cobertura Atenção Primária")
plt.ylabel("Cobertura Vacinal")
plt.savefig('Bahia - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(BA['Média Var Plano'], BA['Média Var CobVac'], c="red")
plt.title("Bahia - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Bahia - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(BA['Média At Pr'], BA['Média Cob Vac'], c="red")
plt.title("Bahia - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Bahia - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(BA['Média Plano'], BA['Média Cob Vac'], c="red")
plt.title("Bahia - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Bahia - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(BA['IDHm'], BA['Média Cob Vac'], c="red")
plt.title("Bahia - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Bahia - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

# %%
CE=dfIR.loc["Ceará"]
plt.scatter(CE['Média Var At Pr'], CE['Média Var CobVac'], c="green")
plt.title("Ceará - Var CobVac VS Var At Pr")
plt.xlabel("Cobertura Atenção Primária")
plt.ylabel("Cobertura Vacinal")
plt.savefig('Ceará - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(CE['Média Var Plano'], CE['Média Var CobVac'], c="green")
plt.title("Ceará - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Ceará - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(CE['Média At Pr'], CE['Média Cob Vac'], c="green")
plt.title("Ceará - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Ceará - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(CE['Média Plano'], CE['Média Cob Vac'], c="green")
plt.title("Ceará - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Ceará - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(CE['IDHm'], CE['Média Cob Vac'], c="green")
plt.title("Ceará - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Ceará - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

# %%
MA=dfIR.loc["Maranhão"]
plt.scatter(MA['Média Var At Pr'], MA['Média Var CobVac'], c="brown")
plt.title("Maranhão - Var CobVac VS Var At Pr")
plt.xlabel("Cobertura Atenção Primária")
plt.ylabel("Cobertura Vacinal")
plt.savefig('Maranhão - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(MA['Média Var Plano'], MA['Média Var CobVac'], c="brown")
plt.title("Maranhão - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Maranhão - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(MA['Média At Pr'], MA['Média Cob Vac'], c="brown")
plt.title("Maranhão - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Maranhão - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(MA['Média Plano'], MA['Média Cob Vac'], c="brown")
plt.title("Maranhão - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Maranhão - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(MA['IDHm'], MA['Média Cob Vac'], c="brown")
plt.title("Maranhão - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Maranhão - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

# %%
PB=dfIR.loc["Paraíba"]
plt.scatter(PB['Média Var At Pr'], PB['Média Var CobVac'], c="grey")
plt.title("Paraíba - Var CobVac VS Var At Pr")
plt.xlabel("Cobertura Atenção Primária")
plt.ylabel("Cobertura Vacinal")
plt.savefig('Paraíba - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(PB['Média Var Plano'], PB['Média Var CobVac'], c="grey")
plt.title("Paraíba - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Paraíba - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(PB['Média At Pr'], PB['Média Cob Vac'], c="grey")
plt.title("Paraíba - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Paraíba - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(PB['Média Plano'], PB['Média Cob Vac'], c="grey")
plt.title("Paraíba - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Paraíba - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(PB['IDHm'], PB['Média Cob Vac'], c="grey")
plt.title("Paraíba - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Paraíba - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

# %%
PE=dfIR.loc["Pernambuco"]
plt.scatter(PE['Média Var At Pr'], PE['Média Var CobVac'], c="magenta")
plt.title("Pernambuco - Var CobVac VS Var At Pr")
plt.xlabel("Variação Cobertura Atenção Primária")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Pernambuco - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(PE['Média Var Plano'], PE['Média Var CobVac'], c="magenta")
plt.title("Pernambuco - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Pernambuco - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(PE['Média At Pr'], PE['Média Cob Vac'], c="magenta")
plt.title("Pernambuco - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Pernambuco - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(PE['Média Plano'], PE['Média Cob Vac'], c="magenta")
plt.title("Pernambuco - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Pernambuco - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(PE['IDHm'], PE['Média Cob Vac'], c="magenta")
plt.title("Pernambuco - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Pernambuco - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

# %%
PI=dfIR.loc["Piauí"]
plt.scatter(PI['Média Var At Pr'], PI['Média Var CobVac'], c="Navy")
plt.title("Piauí - Var CobVac VS Var At Pr")
plt.xlabel("Variação Cobertura Atenção Primária")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Piauí - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(PI['Média Var Plano'], PI['Média Var CobVac'], c="Navy")
plt.title("Piauí - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Piauí - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(PI['Média At Pr'], PI['Média Cob Vac'], c="Navy")
plt.title("Piauí - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Piauí - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(PI['Média Plano'], PI['Média Cob Vac'], c="Navy")
plt.title("Piauí - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Piauí - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(PI['IDHm'], PI['Média Cob Vac'], c="Navy")
plt.title("Piauí - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Piauí - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

# %%
RN=dfIR.loc["Rio Grande do Norte"]
plt.scatter(RN['Média Var At Pr'], RN['Média Var CobVac'], c="Cyan")
plt.title("Rio Grande do Norte - Var CobVac VS Var At Pr")
plt.xlabel("Variação Cobertura Atenção Primária")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Rio Grande do Norte - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(RN['Média Var Plano'], RN['Média Var CobVac'], c="Cyan")
plt.title("Rio Grande do Norte - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Rio Grande do Norte - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(RN['Média At Pr'], RN['Média Cob Vac'], c="Cyan")
plt.title("Rio Grande do Norte - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Rio Grande do Norte - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(RN['Média Plano'], RN['Média Cob Vac'], c="Cyan")
plt.title("Rio Grande do Norte - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Rio Grande do Norte - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(RN['IDHm'], RN['Média Cob Vac'], c="Cyan")
plt.title("Rio Grande do Norte - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Rio Grande do Norte - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

# %%
SE=dfIR.loc["Sergipe"]
plt.scatter(SE['Média Var At Pr'], SE['Média Var CobVac'], c="orange")
plt.title("Sergipe - Var CobVac VS Var At Pr")
plt.xlabel("Variação Cobertura Atenção Primária")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Sergipe - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(SE['Média Var Plano'], SE['Média Var CobVac'], c="orange")
plt.title("Sergipe - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Sergipe - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(SE['Média At Pr'], SE['Média Cob Vac'], c="orange")
plt.title("Sergipe - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Sergipe - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(SE['Média Plano'], SE['Média Cob Vac'], c="orange")
plt.title("Sergipe - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Sergipe - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(SE['IDHm'], SE['Média Cob Vac'], c="orange")
plt.title("Sergipe - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Sergipe - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

# %%
#Gráficos região Nordeste

ND1=plt.scatter(BA['Média Var At Pr'], BA['Média Var CobVac'], c="red")
ND1=plt.scatter(SE['Média Var At Pr'], SE['Média Var CobVac'], c="orange")
ND1=plt.scatter(PI['Média Var At Pr'], PI['Média Var CobVac'], c="Yellow")
ND1=plt.scatter(PE['Média Var At Pr'], PE['Média Var CobVac'], c="magenta")
ND1=plt.scatter(MA['Média Var At Pr'], MA['Média Var CobVac'], c="brown")
ND1=plt.scatter(PB['Média Var At Pr'], PB['Média Var CobVac'], c="grey")
ND1=plt.scatter(CE['Média Var At Pr'], CE['Média Var CobVac'], c="green")
ND1=plt.scatter(AL['Média Var At Pr'], AL['Média Var CobVac'], c="blue")
ND1=plt.scatter(RN['Média Var At Pr'], RN['Média Var CobVac'], c="Cyan")
plt.xlim([-0.2, 0.5])
plt.ylim([-0.1, 1.5])
plt.title("Região Nordeste - Var CobVac VS Var At Pr")
plt.xlabel("Variação Cobertura Atenção Primária")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Nordeste2 - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()


ND2=plt.scatter(BA['Média Var Plano'], BA['Média Var CobVac'], c="red")
ND2=plt.scatter(SE['Média Var Plano'], SE['Média Var CobVac'], c="orange")
ND2=plt.scatter(RN['Média Var Plano'], RN['Média Var CobVac'], c="Cyan")
ND2=plt.scatter(PI['Média Var Plano'], PI['Média Var CobVac'], c="Yellow")
ND2=plt.scatter(PE['Média Var Plano'], PE['Média Var CobVac'], c="magenta")
ND2=plt.scatter(PB['Média Var Plano'], PB['Média Var CobVac'], c="grey")
ND2=plt.scatter(MA['Média Var Plano'], MA['Média Var CobVac'], c="brown")
ND2=plt.scatter(CE['Média Var Plano'], CE['Média Var CobVac'], c="green")
ND2=plt.scatter(AL['Média Var Plano'], AL['Média Var CobVac'], c="blue")
plt.xlim([-0.2, 1])
plt.ylim([-0.1, 1.5])
plt.title("Região Nordeste - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Nordeste2 - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

ND3=plt.scatter(BA['Média At Pr'], BA['Média Cob Vac'], c="red")
ND3=plt.scatter(SE['Média At Pr'], SE['Média Cob Vac'], c="orange")
ND3=plt.scatter(RN['Média At Pr'], RN['Média Cob Vac'], c="Cyan")
ND3=plt.scatter(PI['Média At Pr'], PI['Média Cob Vac'], c="Yellow")
ND3=plt.scatter(PE['Média At Pr'], PE['Média Cob Vac'], c="magenta")
ND3=plt.scatter(PB['Média At Pr'], PB['Média Cob Vac'], c="grey")
ND3=plt.scatter(MA['Média At Pr'], MA['Média Cob Vac'], c="brown")
ND3=plt.scatter(CE['Média At Pr'], CE['Média Cob Vac'], c="green")
ND3=plt.scatter(AL['Média At Pr'], AL['Média Cob Vac'], c="blue")
plt.title("Região Nordeste - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Nordeste - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

ND4=plt.scatter(BA['Média Plano'], BA['Média Cob Vac'], c="red")
ND4=plt.scatter(SE['Média Plano'], SE['Média Cob Vac'], c="orange")
ND4=plt.scatter(RN['Média Plano'], RN['Média Cob Vac'], c="Cyan")
ND4=plt.scatter(PI['Média Plano'], PI['Média Cob Vac'], c="Yellow")
ND4=plt.scatter(PE['Média Plano'], PE['Média Cob Vac'], c="magenta")
ND4=plt.scatter(PB['Média Plano'], PB['Média Cob Vac'], c="grey")
ND4=plt.scatter(MA['Média Plano'], MA['Média Cob Vac'], c="brown")
ND4=plt.scatter(CE['Média Plano'], CE['Média Cob Vac'], c="green")
ND4=plt.scatter(AL['Média Plano'], AL['Média Cob Vac'], c="blue")
plt.title("Região Nordeste - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Nordeste - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

ND5=plt.scatter(BA['IDHm'], BA['Média Cob Vac'], c="red")
ND5=plt.scatter(SE['IDHm'], SE['Média Cob Vac'], c="orange")
ND5=plt.scatter(RN['IDHm'], RN['Média Cob Vac'], c="Cyan")
ND5=plt.scatter(PI['IDHm'], PI['Média Cob Vac'], c="Yellow")
ND5=plt.scatter(PE['IDHm'], PE['Média Cob Vac'], c="magenta")
ND5=plt.scatter(PB['IDHm'], PB['Média Cob Vac'], c="grey")
ND5=plt.scatter(MA['IDHm'], MA['Média Cob Vac'], c="brown")
ND5=plt.scatter(CE['IDHm'], CE['Média Cob Vac'], c="green")
ND5=plt.scatter(AL['IDHm'], AL['Média Cob Vac'], c="blue")
plt.title("Região Nordeste - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Nordeste - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

ND6=plt.scatter(BA['gini'], BA['Média Cob Vac'], c="red")
ND6=plt.scatter(SE['gini'], SE['Média Cob Vac'], c="orange")
ND6=plt.scatter(RN['gini'], RN['Média Cob Vac'], c="Cyan")
ND6=plt.scatter(PI['gini'], PI['Média Cob Vac'], c="Yellow")
ND6=plt.scatter(PE['gini'], PE['Média Cob Vac'], c="magenta")
ND6=plt.scatter(PB['gini'], PB['Média Cob Vac'], c="grey")
ND6=plt.scatter(MA['gini'], MA['Média Cob Vac'], c="brown")
ND6=plt.scatter(CE['gini'], CE['Média Cob Vac'], c="green")
ND6=plt.scatter(AL['gini'], AL['Média Cob Vac'], c="blue")
plt.title("Região Nordeste - Média CobVac VS Gini")
plt.xlabel("Gini")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Nordeste - Média CobVac VS Gini.jpg', format='jpg')
plt.show()
plt.clf()

ND7=plt.scatter(BA['Média_pct_pop0a4'], BA['Média Cob Vac'], c="red")
ND7=plt.scatter(SE['Média_pct_pop0a4'], SE['Média Cob Vac'], c="orange")
ND7=plt.scatter(RN['Média_pct_pop0a4'], RN['Média Cob Vac'], c="Cyan")
ND7=plt.scatter(PI['Média_pct_pop0a4'], PI['Média Cob Vac'], c="Yellow")
ND7=plt.scatter(PE['Média_pct_pop0a4'], PE['Média Cob Vac'], c="magenta")
ND7=plt.scatter(PB['Média_pct_pop0a4'], PB['Média Cob Vac'], c="grey")
ND7=plt.scatter(MA['Média_pct_pop0a4'], MA['Média Cob Vac'], c="brown")
ND7=plt.scatter(CE['Média_pct_pop0a4'], CE['Média Cob Vac'], c="green")
ND7=plt.scatter(AL['Média_pct_pop0a4'], AL['Média Cob Vac'], c="blue")
plt.title("Região Nordeste - Média CobVac VS População de 0 a 4 anos")
plt.xlabel("População de 0 a 4 anos")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Nordeste - Média CobVac VS População de 0 a 4 anos.jpg', format='jpg')
plt.show()
plt.clf()

ND8=plt.scatter(BA['pct_san_adeq'], BA['Média Cob Vac'], c="red")
ND8=plt.scatter(SE['pct_san_adeq'], SE['Média Cob Vac'], c="orange")
ND8=plt.scatter(RN['pct_san_adeq'], RN['Média Cob Vac'], c="Cyan")
ND8=plt.scatter(PI['pct_san_adeq'], PI['Média Cob Vac'], c="Yellow")
ND8=plt.scatter(PE['pct_san_adeq'], PE['Média Cob Vac'], c="magenta")
ND8=plt.scatter(PB['pct_san_adeq'], PB['Média Cob Vac'], c="grey")
ND8=plt.scatter(MA['pct_san_adeq'], MA['Média Cob Vac'], c="brown")
ND8=plt.scatter(CE['pct_san_adeq'], CE['Média Cob Vac'], c="green")
ND8=plt.scatter(AL['pct_san_adeq'], AL['Média Cob Vac'], c="blue")
plt.title("Região Nordeste - Média CobVac VS Saneamento Básico Adequado")
plt.xlabel("Saneamento Básico Adequado")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Nordeste - Média CobVac VS Saneamento Básico Adequado.jpg', format='jpg')
plt.show()
plt.clf()

ND9=plt.scatter(BA['média_pct_ben_bf'], BA['Média Cob Vac'], c="red")
ND9=plt.scatter(SE['média_pct_ben_bf'], SE['Média Cob Vac'], c="orange")
ND9=plt.scatter(RN['média_pct_ben_bf'], RN['Média Cob Vac'], c="Cyan")
ND9=plt.scatter(PI['média_pct_ben_bf'], PI['Média Cob Vac'], c="Yellow")
ND9=plt.scatter(PE['média_pct_ben_bf'], PE['Média Cob Vac'], c="magenta")
ND9=plt.scatter(PB['média_pct_ben_bf'], PB['Média Cob Vac'], c="grey")
ND9=plt.scatter(MA['média_pct_ben_bf'], MA['Média Cob Vac'], c="brown")
ND9=plt.scatter(CE['média_pct_ben_bf'], CE['Média Cob Vac'], c="green")
ND9=plt.scatter(AL['média_pct_ben_bf'], AL['Média Cob Vac'], c="blue")
plt.title("Região Nordeste - Média CobVac VS Beneficiários Bolsa Família")
plt.xlabel("Beneficiários Bolsa Família")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Nordeste - Média CobVac VS Beneficiários Bolsa Família.jpg', format='jpg')
plt.show()
plt.clf()

# %% [markdown]
# ### Norte

# %%
AC=dfIR.loc["Acre"]
plt.scatter(AC['Média Var At Pr'], AC['Média Var CobVac'], c="red")
plt.title("Acre - Var CobVac VS Var At Pr")
plt.xlabel("Variação Cobertura Atenção Primária")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Acre - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(AC['Média Var Plano'], AC['Média Var CobVac'], c="red")
plt.title("Acre - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Acre - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(AC['Média At Pr'], AC['Média Cob Vac'], c="red")
plt.title("Acre - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Acre - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(AC['Média Plano'], AC['Média Cob Vac'], c="red")
plt.title("Acre - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Acre - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(AC['IDHm'], AC['Média Cob Vac'], c="red")
plt.title("Acre - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Acre - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

# %%
AP=dfIR.loc["Amapá"]
plt.scatter(AP['Média Var At Pr'], AP['Média Var CobVac'], c="blue")
plt.title("Amapá - Var CobVac VS Var At Pr")
plt.xlabel("Variação Cobertura Atenção Primária")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Amapá - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(AP['Média Var Plano'], AP['Média Var CobVac'], c="blue")
plt.title("Amapá - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Amapá - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(AP['Média At Pr'], AP['Média Cob Vac'], c="blue")
plt.title("Amapá - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Amapá - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(AP['Média Plano'], AP['Média Cob Vac'], c="blue")
plt.title("Amapá - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Amapá - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(AP['IDHm'], AP['Média Cob Vac'], c="blue")
plt.title("Amapá - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Amapá - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

# %%
AM=dfIR.loc["Amazonas"]
plt.scatter(AM['Média Var At Pr'], AM['Média Var CobVac'], c="green")
plt.title("Amazonas - Var CobVac VS Var At Pr")
plt.xlabel("Variação Cobertura Atenção Primária")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Amazonas - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(AM['Média Var Plano'], AM['Média Var CobVac'], c="green")
plt.title("Amazonas - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Amazonas - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(AM['Média At Pr'], AM['Média Cob Vac'], c="green")
plt.title("Amazonas - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Amazonas - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(AM['Média Plano'], AM['Média Cob Vac'], c="green")
plt.title("Amazonas - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Amazonas - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(AM['IDHm'], AM['Média Cob Vac'], c="green")
plt.scatter(AP['IDHm'], AP['Média Cob Vac'], c="blue")
plt.scatter(AC['IDHm'], AC['Média Cob Vac'], c="red")
plt.title("Amazonas - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Amazonas - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

# %%
PR=dfIR.loc["Pará"]
plt.scatter(PR['Média Var At Pr'], PR['Média Var CobVac'], c="purple")
plt.title("Pará - Var CobVac VS Var At Pr")
plt.xlabel("Variação Cobertura Atenção Primária")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Pará - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(PR['Média Var Plano'], PR['Média Var CobVac'], c="purple")
plt.title("Pará - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Pará - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(PR['Média At Pr'], PR['Média Cob Vac'], c="purple")
plt.title("Pará - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Pará - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(PR['Média Plano'], PR['Média Cob Vac'], c="purple")
plt.title("Pará - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Pará - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(PR['IDHm'], PR['Média Cob Vac'], c="purple")
plt.title("Pará - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Pará - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

# %%
RO=dfIR.loc["Rondônia"]
plt.scatter(RO['Média Var At Pr'], RO['Média Var CobVac'], c="brown")
plt.title("Rondônia - Var CobVac VS Var At Pr")
plt.xlabel("Variação Cobertura Atenção Primária")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Rondônia - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(RO['Média Var Plano'], RO['Média Var CobVac'], c="brown")
plt.title("Rondônia - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Rondônia - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(RO['Média At Pr'], RO['Média Cob Vac'], c="brown")
plt.title("Rondônia - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Rondônia - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(RO['Média Plano'], RO['Média Cob Vac'], c="brown")
plt.title("Rondônia - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Rondônia - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(RO['IDHm'], RO['Média Cob Vac'], c="brown")
plt.title("Rondônia - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Rondônia - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

# %%
RR=dfIR.loc["Roraima"]
plt.scatter(RR['Média Var At Pr'], RR['Média Var CobVac'], c="grey")
plt.title("Roraima - Var CobVac VS Var At Pr")
plt.xlabel("Variação Cobertura Atenção Primária")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Roraima - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(RR['Média Var Plano'], RR['Média Var CobVac'], c="grey")
plt.title("Roraima - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Roraima - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(RR['Média At Pr'], RR['Média Cob Vac'], c="grey")
plt.title("Roraima - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Roraima - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(RR['Média Plano'], RR['Média Cob Vac'], c="grey")
plt.title("Roraima - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Roraima - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(RR['IDHm'], RR['Média Cob Vac'], c="grey")
plt.title("Roraima - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Roraima - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

# %%
TO=dfIR.loc["Tocantins"]
plt.scatter(TO['Média Var At Pr'], TO['Média Var CobVac'], c="magenta")
plt.title("Tocantins - Var CobVac VS Var At Pr")
plt.xlabel("Variação Cobertura Atenção Primária")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Tocantins - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(TO['Média Var Plano'], TO['Média Var CobVac'], c="magenta")
plt.title("Tocantins - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Tocantins - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(TO['Média At Pr'], TO['Média Cob Vac'], c="magenta")
plt.title("Tocantins - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Tocantins - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(TO['Média Plano'], TO['Média Cob Vac'], c="magenta")
plt.title("Tocantins - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Tocantins - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(TO['IDHm'], TO['Média Cob Vac'], c="magenta")
plt.title("Tocantins - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Tocantins - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

# %%
#Gráficos região Norte

NO1=plt.scatter(TO['Média Var At Pr'], TO['Média Var CobVac'], c="magenta")
NO1=plt.scatter(RR['Média Var At Pr'], RR['Média Var CobVac'], c="grey")
NO1=plt.scatter(RO['Média Var At Pr'], RO['Média Var CobVac'], c="brown")
NO1=plt.scatter(PR['Média Var At Pr'], PR['Média Var CobVac'], c="purple")
NO1=plt.scatter(AM['Média Var At Pr'], AM['Média Var CobVac'], c="green")
NO1=plt.scatter(AP['Média Var At Pr'], AP['Média Var CobVac'], c="blue")
NO1=plt.scatter(AC['Média Var At Pr'], AC['Média Var CobVac'], c="red")
plt.xlim([-0.2, 0.5])
plt.ylim([-0.2, 0.5])
plt.title("Região Norte - Var CobVac VS Var At Pr")
plt.xlabel("Variação Cobertura Atenção Primária")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Norte2 - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

NO2=plt.scatter(TO['Média Var Plano'], TO['Média Var CobVac'], c="magenta")
NO2=plt.scatter(RR['Média Var Plano'], RR['Média Var CobVac'], c="grey")
NO2=plt.scatter(RO['Média Var Plano'], RO['Média Var CobVac'], c="brown")
NO2=plt.scatter(PR['Média Var Plano'], PR['Média Var CobVac'], c="purple")
NO2=plt.scatter(AM['Média Var Plano'], AM['Média Var CobVac'], c="green")
NO2=plt.scatter(AP['Média Var Plano'], AP['Média Var CobVac'], c="blue")
NO2=plt.scatter(AC['Média Var Plano'], AC['Média Var CobVac'], c="red")
plt.xlim([-0.3, 1])
plt.ylim([-0.2, 0.5])
plt.title("Região Norte - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Norte2 - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

NO3=plt.scatter(PR['Média At Pr'], PR['Média Cob Vac'], c="purple")
NO3=plt.scatter(TO['Média At Pr'], TO['Média Cob Vac'], c="magenta")
NO3=plt.scatter(AC['Média At Pr'], AC['Média Cob Vac'], c="red")
NO3=plt.scatter(AP['Média At Pr'], AP['Média Cob Vac'], c="blue")
NO3=plt.scatter(AM['Média At Pr'], AM['Média Cob Vac'], c="green")
NO3=plt.scatter(RO['Média At Pr'], RO['Média Cob Vac'], c="brown")
NO3=plt.scatter(RR['Média At Pr'], RR['Média Cob Vac'], c="grey")
plt.title("Região Norte - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Norte - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()


NO4=plt.scatter(TO['Média Plano'], TO['Média Cob Vac'], c="magenta")
NO4=plt.scatter(RO['Média Plano'], RO['Média Cob Vac'], c="brown")
NO4=plt.scatter(PR['Média Plano'], PR['Média Cob Vac'], c="purple")
NO4=plt.scatter(AM['Média Plano'], AM['Média Cob Vac'], c="green")
NO4=plt.scatter(AP['Média Plano'], AP['Média Cob Vac'], c="blue")
NO4=plt.scatter(AC['Média Plano'], AC['Média Cob Vac'], c="red")
NO4=plt.scatter(RR['Média Plano'], RR['Média Cob Vac'], c="grey")
plt.title("Região Norte - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Norte - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()


NO5=plt.scatter(PR['IDHm'], PR['Média Cob Vac'], c="purple")
NO5=plt.scatter(TO['IDHm'], TO['Média Cob Vac'], c="magenta")
NO5=plt.scatter(RO['IDHm'], RO['Média Cob Vac'], c="brown")
NO5=plt.scatter(AM['IDHm'], AM['Média Cob Vac'], c="green")
NO5=plt.scatter(AP['IDHm'], AP['Média Cob Vac'], c="blue")
NO5=plt.scatter(AC['IDHm'], AC['Média Cob Vac'], c="red")
NO5=plt.scatter(RR['IDHm'], RR['Média Cob Vac'], c="grey")
plt.title("Região Norte - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Norte - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

NO6=plt.scatter(PR['gini'], PR['Média Cob Vac'], c="purple")
NO6=plt.scatter(TO['gini'], TO['Média Cob Vac'], c="magenta")
NO6=plt.scatter(RO['gini'], RO['Média Cob Vac'], c="brown")
NO6=plt.scatter(AM['gini'], AM['Média Cob Vac'], c="green")
NO6=plt.scatter(AP['gini'], AP['Média Cob Vac'], c="blue")
NO6=plt.scatter(AC['gini'], AC['Média Cob Vac'], c="red")
NO6=plt.scatter(RR['gini'], RR['Média Cob Vac'], c="grey")
plt.title("Região Norte - Média CobVac VS Gini")
plt.xlabel("Gini")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Norte - Média CobVac VS Gini.jpg', format='jpg')
plt.show()
plt.clf()

NO7=plt.scatter(PR['Média_pct_pop0a4'], PR['Média Cob Vac'], c="purple")
NO7=plt.scatter(TO['Média_pct_pop0a4'], TO['Média Cob Vac'], c="magenta")
NO7=plt.scatter(RO['Média_pct_pop0a4'], RO['Média Cob Vac'], c="brown")
NO7=plt.scatter(AM['Média_pct_pop0a4'], AM['Média Cob Vac'], c="green")
NO7=plt.scatter(AP['Média_pct_pop0a4'], AP['Média Cob Vac'], c="blue")
NO7=plt.scatter(AC['Média_pct_pop0a4'], AC['Média Cob Vac'], c="red")
NO7=plt.scatter(RR['Média_pct_pop0a4'], RR['Média Cob Vac'], c="grey")
plt.title("Região Norte - Média CobVac VS População de 0 a 4 anos")
plt.xlabel("População de 0 a 4 anos")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Norte - Média CobVac VS População de 0 a 4 anos.jpg', format='jpg')
plt.show()
plt.clf()

NO8=plt.scatter(PR['pct_san_adeq'], PR['Média Cob Vac'], c="purple")
NO8=plt.scatter(TO['pct_san_adeq'], TO['Média Cob Vac'], c="magenta")
NO8=plt.scatter(RO['pct_san_adeq'], RO['Média Cob Vac'], c="brown")
NO8=plt.scatter(AM['pct_san_adeq'], AM['Média Cob Vac'], c="green")
NO8=plt.scatter(AP['pct_san_adeq'], AP['Média Cob Vac'], c="blue")
NO8=plt.scatter(AC['pct_san_adeq'], AC['Média Cob Vac'], c="red")
NO8=plt.scatter(RR['pct_san_adeq'], RR['Média Cob Vac'], c="grey")
plt.title("Região Norte - Média CobVac VS Saneamento Básico Adequado")
plt.xlabel("Saneamento Básico Adequado")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Norte - Média CobVac VS Saneamento Básico Adequado.jpg', format='jpg')
plt.show()
plt.clf()

NO9=plt.scatter(PR['média_pct_ben_bf'], PR['Média Cob Vac'], c="purple")
NO9=plt.scatter(TO['média_pct_ben_bf'], TO['Média Cob Vac'], c="magenta")
NO9=plt.scatter(RO['média_pct_ben_bf'], RO['Média Cob Vac'], c="brown")
NO9=plt.scatter(AM['média_pct_ben_bf'], AM['Média Cob Vac'], c="green")
NO9=plt.scatter(AP['média_pct_ben_bf'], AP['Média Cob Vac'], c="blue")
NO9=plt.scatter(AC['média_pct_ben_bf'], AC['Média Cob Vac'], c="red")
NO9=plt.scatter(RR['média_pct_ben_bf'], RR['Média Cob Vac'], c="grey")
plt.title("Região Norte - Média CobVac VS Beneficiários Bolsa Família")
plt.xlabel("Beneficiários Bolsa Família")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Norte - Média CobVac VS Beneficiários Bolsa Família.jpg', format='jpg')
plt.show()
plt.clf()

# %% [markdown]
# ### Sul

# %%
PR=dfIR.loc["Paraná"]
plt.scatter(PR['Média Var At Pr'], PR['Média Var CobVac'], c="blue")
plt.title("Paraná - Var CobVac VS Var At Pr")
plt.xlabel("Variação Cobertura Atenção Primária")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Paraná - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(PR['Média Var Plano'], PR['Média Var CobVac'], c="blue")
plt.title("Paraná - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Paraná - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(PR['Média At Pr'], PR['Média Cob Vac'], c="blue")
plt.title("Paraná - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Paraná - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(PR['Média Plano'], PR['Média Cob Vac'], c="blue")
plt.title("Paraná - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Paraná - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(PR['IDHm'], PR['Média Cob Vac'], c="blue")
plt.title("Paraná - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Paraná - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

# %%
SC=dfIR.loc["Santa Catarina"]
plt.scatter(SC['Média Var At Pr'], SC['Média Var CobVac'], c="green")
plt.title("Santa Catarina - Var CobVac VS Var At Pr")
plt.xlabel("Variação Cobertura Atenção Primária")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Santa Catarina - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(SC['Média Var Plano'], SC['Média Var CobVac'], c="green")
plt.title("Santa Catarina - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Santa Catarina - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(SC['Média At Pr'], SC['Média Cob Vac'], c="green")
plt.title("Santa Catarina - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Santa Catarina - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(SC['Média Plano'], SC['Média Cob Vac'], c="green")
plt.title("Santa Catarina - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Santa Catarina - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(SC['IDHm'], SC['Média Cob Vac'], c="green")
plt.title("Santa Catarina - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Santa Catarina - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

# %%
RS=dfIR.loc["Rio Grande do Sul"]
plt.scatter(RS['Média Var At Pr'], RS['Média Var CobVac'], c="red")
plt.title("Rio Grande do Sul - Var CobVac VS Var At Pr")
plt.xlabel("Variação Cobertura Atenção Primária")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Rio Grande do Sul - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(RS['Média Var Plano'], RS['Média Var CobVac'], c="red")
plt.title("Rio Grande do Sul - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Rio Grande do Sul - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(RS['Média At Pr'], RS['Média Cob Vac'], c="red")
plt.title("Rio Grande do Sul - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Rio Grande do Sul - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(RS['Média Plano'], RS['Média Cob Vac'], c="red")
plt.title("Rio Grande do Sul - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Rio Grande do Sul - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

plt.scatter(RS['IDHm'], RS['Média Cob Vac'], c="red")
plt.title("Rio Grande do Sul - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Rio Grande do Sul - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

# %%
#Gráficos região Sul

SU1=plt.scatter(PR['Média Var At Pr'], PR['Média Var CobVac'], c="blue")
SU1=plt.scatter(RS['Média Var At Pr'], RS['Média Var CobVac'], c="red")
SU1=plt.scatter(SC['Média Var At Pr'], SC['Média Var CobVac'], c="green")
plt.xlim([-0.1, 0.2])
plt.ylim([-0.2, 0.5])
plt.title("Região Sul - Var CobVac VS Var At Pr")
plt.xlabel("Variação Cobertura Atenção Primária")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Sul2 - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

SU2=plt.scatter(RS['Média Var Plano'], RS['Média Var CobVac'], c="red")
SU2=plt.scatter(PR['Média Var Plano'], PR['Média Var CobVac'], c="blue")
SU2=plt.scatter(SC['Média Var Plano'], SC['Média Var CobVac'], c="green")
plt.xlim([-0.2, 0.3])
plt.ylim([-0.2, 0.5])
plt.title("Região Sul - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde")
plt.ylabel("Variação Cobertura Vacinal")
plt.savefig('Sul2 - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

SU3=plt.scatter(PR['Média At Pr'], PR['Média Cob Vac'], c="blue")
SU3=plt.scatter(RS['Média At Pr'], RS['Média Cob Vac'], c="red")
SU3=plt.scatter(SC['Média At Pr'], SC['Média Cob Vac'], c="green")
plt.title("Região Sul - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Sul - Média CobVac VS Média At Pr.jpg', format='jpg')
plt.show()
plt.clf()

SU4=plt.scatter(PR['Média Plano'], PR['Média Cob Vac'], c="blue")
SU4=plt.scatter(RS['Média Plano'], RS['Média Cob Vac'], c="red")
SU4=plt.scatter(SC['Média Plano'], SC['Média Cob Vac'], c="green")
plt.title("Região Sul - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Sul - Média CobVac VS Média Plano.jpg', format='jpg')
plt.show()
plt.clf()

SU5=plt.scatter(PR['IDHm'], PR['Média Cob Vac'], c="blue")
SU5=plt.scatter(RS['IDHm'], RS['Média Cob Vac'], c="red")
SU5=plt.scatter(SC['IDHm'], SC['Média Cob Vac'], c="green")
plt.title("Região Sul - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Sul - Média CobVac VS IDHm.jpg', format='jpg')
plt.show()
plt.clf()

SU6=plt.scatter(PR['gini'], PR['Média Cob Vac'], c="blue")
SU6=plt.scatter(RS['gini'], RS['Média Cob Vac'], c="red")
SU6=plt.scatter(SC['gini'], SC['Média Cob Vac'], c="green")
plt.title("Região Sul - Média CobVac VS Gini")
plt.xlabel("Gini")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Sul - Média CobVac VS Gini.jpg', format='jpg')
plt.show()
plt.clf()

SU7=plt.scatter(PR['Média_pct_pop0a4'], PR['Média Cob Vac'], c="blue")
SU7=plt.scatter(RS['Média_pct_pop0a4'], RS['Média Cob Vac'], c="red")
SU7=plt.scatter(SC['Média_pct_pop0a4'], SC['Média Cob Vac'], c="green")
plt.title("Região Sul - Média CobVac VS População de 0 a 4 anos")
plt.xlabel("População de 0 a 4 anos")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Sul - Média CobVac VS População de 0 a 4 anos.jpg', format='jpg')
plt.show()
plt.clf()

SU8=plt.scatter(PR['pct_san_adeq'], PR['Média Cob Vac'], c="blue")
SU8=plt.scatter(RS['pct_san_adeq'], RS['Média Cob Vac'], c="red")
SU8=plt.scatter(SC['pct_san_adeq'], SC['Média Cob Vac'], c="green")
plt.title("Região Sul - Média CobVac VS Saneamento Básico Adequado")
plt.xlabel("Saneamento Básico Adequado")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Sul - Média CobVac VS Saneamento Básico Adequado.jpg', format='jpg')
plt.show()
plt.clf()

SU9=plt.scatter(PR['média_pct_ben_bf'], PR['Média Cob Vac'], c="blue")
SU9=plt.scatter(RS['média_pct_ben_bf'], RS['Média Cob Vac'], c="red")
SU9=plt.scatter(SC['média_pct_ben_bf'], SC['Média Cob Vac'], c="green")
plt.title("Região Sul - Média CobVac VS Beneficiários Bolsa Família")
plt.xlabel("Beneficiários Bolsa Família")
plt.ylabel("Média Cobertura Vacinal")
plt.savefig('Sul - Média CobVac VS Beneficiários Bolsa Família.jpg', format='jpg')
plt.show()
plt.clf()

# %% [markdown]
# # Gráfico dispersão Brasil e matrizes de correlação por regiões

# %%
dfIR = pd.read_csv("DadosCompletos.csv", index_col=0)
#print(dfIR)

# %%
CO=dfIR.loc['Centro Oeste']
ND=dfIR.loc['Nordeste']
NO=dfIR.loc['Norte']
SD=dfIR.loc['Sudeste']
SU=dfIR.loc['Sul']

G1=plt.scatter(ND['Média Var At Pr'], ND['Média Var CobVac'], c=["blue"],alpha=0.7)
G1=plt.scatter(SD['Média Var At Pr'], SD['Média Var CobVac'], c=["orange"],)
G1=plt.scatter(NO['Média Var At Pr'], NO['Média Var CobVac'], c=["purple"],alpha=0.7)
G1=plt.scatter(CO['Média Var At Pr'], CO['Média Var CobVac'], c=["red"])
G1=plt.scatter(SU['Média Var At Pr'], SU['Média Var CobVac'], c=["green"],alpha=0.7)
#plt.xlim([-0.2, 1])
#plt.ylim([-0.2, 1])
plt.title("Regiões do Brasil - Var CobVac VS Var At Pr")
plt.xlabel("Variação Cobertura Atenção Primária (%)")
plt.ylabel("Variação Cobertura Vacinal (%)")
plt.savefig('Regiões do Brasil - Var CobVac VS Var At Pr.jpg', format='jpg')
plt.show()
plt.clf()

G2=plt.scatter(ND['Média Var Plano'], ND['Média Var CobVac'], c=["blue"],alpha=0.7)
G2=plt.scatter(SD['Média Var Plano'], SD['Média Var CobVac'], c=["orange"],)
G2=plt.scatter(NO['Média Var Plano'], NO['Média Var CobVac'], c=["purple"],alpha=0.7)
G2=plt.scatter(CO['Média Var Plano'], CO['Média Var CobVac'], c=["red"])
G2=plt.scatter(SU['Média Var Plano'], SU['Média Var CobVac'], c=["green"],alpha=0.7)
plt.xlim([-1, 2])
plt.ylim([-0.2, 1.5])
plt.title("Regiões do Brasil - Var CobVac VS Var Plano")
plt.xlabel("Variação Cobertura Plano de Saúde (%)")
plt.ylabel("Variação Cobertura Vacinal (%)")
plt.savefig('Regiões do Brasil2 - Var CobVac VS Var Plano.jpg', format='jpg')
plt.show()
plt.clf()

G3=plt.scatter(ND['Média At Pr'], ND['Média Cob Vac'],s=15 ,c=["red"],alpha=0.7)
G3=plt.scatter(SD['Média At Pr'], SD['Média Cob Vac'], s=15,c=["blue"],)
G3=plt.scatter(NO['Média At Pr'], NO['Média Cob Vac'], s=15,c=["orange"],alpha=0.7)
G3=plt.scatter(CO['Média At Pr'], CO['Média Cob Vac'], s=15,c=["green"])
G3=plt.scatter(SU['Média At Pr'], SU['Média Cob Vac'], s=15,c=["black"],alpha=0.7)
plt.title("Regiões do Brasil - Média CobVac VS Média At Pr")
plt.xlabel("Média Cobertura Atenção Primária (%)")
plt.ylabel("Média Cobertura Vacinal (%)")
#plt.legend(["Nordeste","Sudeste" , "Norte","Centro Oeste","Sul"], ncol = 5 , loc = "lower right")
plt.savefig('Regiões do Brasil - Média CobVac VS Média At Pr.png', format='png')
plt.show()
plt.clf()

G4=plt.scatter(ND['Média Plano'], ND['Média Cob Vac'], s=15,c=["red"],alpha=0.7)
G4=plt.scatter(SD['Média Plano'], SD['Média Cob Vac'], s=15,c=["blue"],)
G4=plt.scatter(NO['Média Plano'], NO['Média Cob Vac'], s=15,c=["orange"],alpha=0.7)
G4=plt.scatter(CO['Média Plano'], CO['Média Cob Vac'],s=15, c=["green"])
G4=plt.scatter(SU['Média Plano'], SU['Média Cob Vac'], s=15,c=["black"],alpha=0.7)
plt.title("Regiões do Brasil - Média CobVac VS Média Plano")
plt.xlabel("Média Cobertura Plano (%)")
plt.ylabel("Média Cobertura Vacinal (%)")
#plt.legend(["Nordeste","Sudeste" , "Norte","Centro Oeste","Sul"], ncol = 1 , loc = "lower right")
plt.savefig('Regiões do Brasil - Média CobVac VS Média Plano.png', format='png')
plt.show()
plt.clf()

G5=plt.scatter(ND['IDHm'], ND['Média Cob Vac'], s=15,c=["red"],alpha=0.7)
G5=plt.scatter(SD['IDHm'], SD['Média Cob Vac'],s=15, c=["blue"],)
G5=plt.scatter(NO['IDHm'], NO['Média Cob Vac'],s=15, c=["orange"],alpha=0.7)
G5=plt.scatter(CO['IDHm'], CO['Média Cob Vac'],s=15, c=["green"])
G5=plt.scatter(SU['IDHm'], SU['Média Cob Vac'], s=15,c=["black"],alpha=0.7)
plt.title("Regiões do Brasil - Média CobVac VS IDHm")
plt.xlabel("IDHm")
plt.ylabel("Média Cobertura Vacinal (%)")
#plt.legend(["Nordeste","Sudeste" , "Norte","Centro Oeste","Sul"], ncol = 1 , loc = "lower right")
plt.savefig('Regiões do Brasil - Média CobVac VS IDHm.png', format='png')
plt.show()
plt.clf()

G6=plt.scatter(ND['gini'], ND['Média Cob Vac'], s=15,c=["red"],alpha=0.7)
G6=plt.scatter(SD['gini'], SD['Média Cob Vac'], s=15,c=["blue"],)
G6=plt.scatter(NO['gini'], NO['Média Cob Vac'],s=15, c=["orange"],alpha=0.7)
G6=plt.scatter(CO['gini'], CO['Média Cob Vac'], s=15,c=["green"])
G6=plt.scatter(SU['gini'], SU['Média Cob Vac'],s=15, c=["black"],alpha=0.7)
plt.title("Regiões do Brasil - Média CobVac VS Gini")
plt.xlabel("Gini")
plt.ylabel("Média Cobertura Vacinal (%)")
#plt.legend(["Nordeste","Sudeste" , "Norte","Centro Oeste","Sul"], ncol = 1 , loc = "lower left")
plt.savefig('Regiões do Brasil - Média CobVac VS Gini.png', format='png')
plt.show()
plt.clf()

G7=plt.scatter(ND['Média_pct_pop0a4']*100, ND['Média Cob Vac'],s=15, c=["red"],alpha=0.7)
G7=plt.scatter(SD['Média_pct_pop0a4']*100, SD['Média Cob Vac'],s=15, c=["blue"],)
G7=plt.scatter(NO['Média_pct_pop0a4']*100, NO['Média Cob Vac'], s=15,c=["orange"],alpha=0.7)
G7=plt.scatter(CO['Média_pct_pop0a4']*100, CO['Média Cob Vac'], s=15,c=["green"])
G7=plt.scatter(SU['Média_pct_pop0a4']*100, SU['Média Cob Vac'], s=15,c=["black"],alpha=0.7)
plt.title("Regiões do Brasil - Média CobVac VS População de 0 a 4 anos")
plt.xlabel("População de 0 a 4 anos (%)")
plt.ylabel("Média Cobertura Vacinal (%)")
#plt.legend(["Nordeste","Sudeste" , "Norte","Centro Oeste","Sul"], ncol = 1 , loc = "lower left")
plt.savefig('Regiões do Brasil - Média CobVac VS População de 0 a 4 anos.png', format='png')
plt.show()
plt.clf()

G8=plt.scatter(ND['pct_san_adeq']*100, ND['Média Cob Vac'], s=15,c=["red"],alpha=0.7)
G8=plt.scatter(SD['pct_san_adeq']*100, SD['Média Cob Vac'], s=15,c=["blue"],)
G8=plt.scatter(NO['pct_san_adeq']*100, NO['Média Cob Vac'], s=15,c=["orange"],alpha=0.7)
G8=plt.scatter(CO['pct_san_adeq']*100, CO['Média Cob Vac'], s=15,c=["green"])
G8=plt.scatter(SU['pct_san_adeq']*100, SU['Média Cob Vac'], s=15,c=["black"],alpha=0.7)
plt.title("Regiões do Brasil - Média CobVac VS Saneamento Básico Adequado")
plt.xlabel("Saneamento Básico Adequado (%)")
plt.ylabel("Média Cobertura Vacinal (%)")
#plt.legend(["Nordeste","Sudeste" , "Norte","Centro Oeste","Sul"], ncol = 1 , loc = "lower right")
plt.savefig('Regiões do Brasil - Média CobVac VS Saneamento Básico Adequado.png', format='png')
plt.show()
plt.clf()

G9=plt.scatter(ND['média_pct_ben_bf']*100, ND['Média Cob Vac'], s=15,c=["red"],alpha=0.7)
G9=plt.scatter(SD['média_pct_ben_bf']*100, SD['Média Cob Vac'], s=15,c=["blue"],)
G9=plt.scatter(NO['média_pct_ben_bf']*100, NO['Média Cob Vac'], s=15,c=["orange"],alpha=0.7)
G9=plt.scatter(CO['média_pct_ben_bf']*100, CO['Média Cob Vac'], s=15,c=["green"])
G9=plt.scatter(SU['média_pct_ben_bf']*100, SU['Média Cob Vac'], s=15,c=["black"],alpha=0.7)
plt.title("Regiões do Brasil - Média CobVac VS Beneficiários Bolsa Família")
plt.xlabel("Beneficiários Bolsa Família (%)")
plt.ylabel("Média Cobertura Vacinal (%)")
#plt.legend(["Nordeste","Sudeste" , "Norte","Centro Oeste","Sul"], ncol = 1 , loc = "lower right")
plt.savefig('Regiões do Brasil - Média CobVac VS Bolsa Família.png', format='png')
plt.show()
plt.clf()

# %%
dfIRm = pd.read_csv("DadosCompletos.csv",index_col=1)
#print(dfIRm)
dfIRm.drop(["CodMuns","Média Var CobVac","Média Var At Pr","Média Var Plano","IDHm_renda","pop_area","Média_pop","Média_pop0a4",
                "area_km2","Densidade","Tipo_Urb","média_familias_bf"], axis=1, inplace=True)
dfIRm.rename(columns = {"Média_pct_pop0a4":'População0a4',"gini":"Gini", "pct_san_adeq":"Saneamento Básico", "média_pct_ben_bf":"Ben Bolsa Família"}, inplace = True)
print(dfIRm)


correlation = dfIRm.corr("spearman")

# %%
plot = sn.heatmap(correlation, annot = True, fmt=".1f", linewidths=.6)
plot
plt.savefig('Matriz Brasil spearman.jpg', format='jpg',bbox_inches ="tight")

# %%
dfSDm = (dfIRm.set_index("Região")).loc["Sudeste"]
dfCOm = (dfIRm.set_index("Região")).loc["Centro Oeste"]
dfSUm = (dfIRm.set_index("Região")).loc["Sul"]
dfNOm = (dfIRm.set_index("Região")).loc["Norte"]
dfNDm = (dfIRm.set_index("Região")).loc["Nordeste"]

# %%
correlationSD = dfSDm.corr(method ='spearman')

plot = sn.heatmap(correlationSD, annot = True, fmt=".1f", linewidths=.6)
plot
plt.savefig('Matriz Sudeste Spearman.jpg', format='jpg', bbox_inches ="tight")

# %%
correlationCO = dfCOm.corr(method ='spearman')

plot = sn.heatmap(correlationCO, annot = True, fmt=".1f", linewidths=.6)
plot
plt.savefig('Matriz Centro Oeste spearman.jpg', format='jpg', bbox_inches ="tight")

# %%
correlationSU = dfSUm.corr(method ='spearman')

plot = sn.heatmap(correlationSU, annot = True, fmt=".1f", linewidths=.6)
plot
plt.savefig('Matriz Sul spearman.jpg', format='jpg', bbox_inches ="tight")

# %%
correlationNO = dfNOm.corr(method ='spearman')

plot = sn.heatmap(correlationNO, annot = True, fmt=".1f", linewidths=.6)
plot
plt.savefig('Matriz Norte spearman.jpg', format='jpg', bbox_inches ="tight")

# %%
correlationND = dfNDm.corr("spearman")

plot = sn.heatmap(correlationND, annot = True, fmt=".1f", linewidths=.6)
plot
plt.savefig('Matriz Nordeste spearman.jpg', format='jpg', bbox_inches ="tight")
